# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
csv_path = os.path.join("..","..","data","train.csv")
csv_path_test = os.path.join("..","..","data","test.csv")
train_data = pd.read_csv(csv_path)
test_data = pd.read_csv(csv_path_test)

# %%
train_data.describe()
# Out:
#               target          var_0          var_1          var_2  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        0.100490      10.679914      -1.627622      10.715192
# std         0.300653       3.040051       4.050044       2.640894
# min         0.000000       0.408400     -15.043400       2.117100
# 25%         0.000000       8.453850      -4.740025       8.722475
# 50%         0.000000      10.524750      -1.608050      10.580000
# 75%         0.000000      12.758200       1.358625      12.516700
# max         1.000000      20.315000      10.376800      19.353000
#
#                var_3          var_4          var_5          var_6  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean        6.796529      11.078333      -5.065317       5.408949
# std         2.043319       1.623150       7.863267       0.866607
# min        -0.040200       5.074800     -32.562600       2.347300
# ...

# %%
test_data.describe()
# Out:
#                var_0          var_1          var_2          var_3  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean       10.658737      -1.624244      10.707452       6.788214
# std         3.036716       4.040509       2.633888       2.052724
# min         0.188700     -15.043400       2.355200      -0.022400
# 25%         8.442975      -4.700125       8.735600       5.230500
# 50%        10.513800      -1.590500      10.560700       6.822350
# 75%        12.739600       1.343400      12.495025       8.327600
# max        22.323400       9.385100      18.714100      13.142000
#
#                var_4          var_5          var_6          var_7  \
# count  200000.000000  200000.000000  200000.000000  200000.000000
# mean       11.076399      -5.050558       5.415164      16.529143
# std         1.616456       7.869293       0.864686       3.424482
# min         5.484400     -27.767000       2.216400       5.713700
# ...

# %% [markdown]
# ### Training and Test datasets look very similar

# %% [markdown]
# <hr>

# %% [markdown]
# ## Is the dataset balanced?

# %%
sns.countplot(train_data.target)

# %% [markdown]
# ### No, there is roughly 90% False, and 10% True

# %% [markdown]
# <br>

# %% [markdown]
# ## Are there any correlations in this dataset?

# %%
correlations = train_data.iloc[:,2:].corr().abs().unstack().sort_values().reset_index()
correlations = correlations[correlations["level_0"] != correlations["level_1"]].rename(columns={0:"correlation_ratio"})
print("Highest Correlations")
print(correlations.tail(10))
print()
print("Lowest Correlations")
print(correlations.head(10))
# Out:
# Highest Correlations
#        level_0  level_1  correlation_ratio
# 39790  var_183  var_189           0.009359
# 39791  var_189  var_183           0.009359
# 39792  var_174   var_81           0.009490
# 39793   var_81  var_174           0.009490
# 39794   var_81  var_165           0.009714
# 39795  var_165   var_81           0.009714
# 39796   var_53  var_148           0.009788
# 39797  var_148   var_53           0.009788
# 39798   var_26  var_139           0.009844
# 39799  var_139   var_26           0.009844
#
# Lowest Correlations
#    level_0  level_1  correlation_ratio
# 0   var_75  var_191       2.703975e-08
# 1  var_191   var_75       2.703975e-08
# 2  var_173    var_6       5.942735e-08
# 3    var_6  var_173       5.942735e-08
# 4  var_126  var_109       1.313947e-07
# 5  var_109  var_126       1.313947e-07
# 6  var_144   var_27       1.772502e-07
# 7   var_27  var_144       1.772502e-07
# 8  var_177  var_100       3.116544e-07
# 9  var_100  var_177       3.116544e-07

# %% [markdown]
# ### There appears to be minimal correlation among variables. The highest correlation is not evel .01 or 1%
# - Is there any correlation with just 0 targets? just 1 targets?

# %% [markdown]
# <hr>

# %% [markdown]
# ## Create new features to use in algorithm.

# %%
def create_features(df):
    df["sum_feature"] = df.iloc[:,2:202].sum(axis=1)
    df["mean_feature"] = df.iloc[:,2:202].mean(axis=1)
    df["std_feature"] = df.iloc[:,2:202].std(axis=1)
    df["Q1_feature"] = df.iloc[:,2:202].quantile(q =.25, axis=1)
    df["median_feature"] = df.iloc[:,2:202].median(axis=1)
    df["Q3_feature"] = df.iloc[:,2:202].quantile(q=.75, axis=1)
    df["skew_feature"] = df.iloc[:,2:202].skew(axis=1)
    df["kurtosis_feature"] = df.iloc[:,2:202].kurtosis(axis=1)
    
    # Maybe add difference between quantiles
    return df

# %%
train_data_new = create_features(train_data.copy())

# %%
train_data_new.head()
# Out:
#    ID_code  target    var_0   var_1    var_2   var_3    var_4   var_5   var_6  \
# 0  train_0       0   8.9255 -6.7863  11.9081  5.0930  11.4607 -9.2834  5.1187
# 1  train_1       0  11.5006 -4.1473  13.8588  5.3890  12.3622  7.0433  5.6208
# 2  train_2       0   8.6093 -2.7457  12.0805  7.8928  10.5825 -9.0837  6.9427
# 3  train_3       0  11.0604 -2.1518   8.9522  7.1957  12.5846 -1.8361  5.8428
# 4  train_4       0   9.8369 -1.4834  12.8746  6.6375  12.2772  2.4486  5.9405
#
#      var_7        ...         var_198  var_199  sum_feature  mean_feature  \
# 0  18.6266        ...         12.7803  -1.0914    1456.3182      7.281591
# 1  16.5338        ...         18.3560   1.9518    1415.3636      7.076818
# 2  14.6155        ...         14.7222   0.3965    1240.8966      6.204483
# 3  14.9250        ...         17.9697  -8.9996    1288.2319      6.441160
# 4  19.2514        ...         17.9974  -8.8104    1354.2310      6.771155
#
# ...

# %% [markdown]
# ## Analyse new features to visualize any value

# %%
sns.set_style("darkgrid")

# define 0 target and 1 target values
train_data_target_0 = train_data_new.loc[train_data_new['target'] == 0]
train_data_target_1 = train_data_new.loc[train_data_new['target'] == 1]

fig, axes = plt.subplots(2, 4, figsize=(30,15))
fig.suptitle("Distribution of new features in the train set", fontsize=20)

for idx in range(0,8):
    
    if idx < 4:
        N=0; M=idx
    else:
        N=1; M=idx-4
    
    sns.distplot(
        train_data_target_0.iloc[:,202+idx], 
        color="red", 
        kde=True, 
        bins=80, 
        label='target = 0',
        ax = axes[N][M]
    )
    sns.distplot(
        train_data_target_1.iloc[:,202+idx], 
        color="blue", 
        kde=True, 
        bins=80,
        label='target = 1',
        ax = axes[N][M]
    )
plt.show()

# %% [markdown]
# ### New Features look very similar for both 0 and 1 tragets.

# %% [markdown]
# <hr>

# %% [markdown]
# ### Looks like all the data goes to 4 decimal places.
# - Can we round and then count number of occurances for each variable (extra 200 columns)?

# %%
train_data.head()
# Out:
#    ID_code  target    var_0   var_1    var_2   var_3    var_4   var_5   var_6  \
# 0  train_0       0   8.9255 -6.7863  11.9081  5.0930  11.4607 -9.2834  5.1187
# 1  train_1       0  11.5006 -4.1473  13.8588  5.3890  12.3622  7.0433  5.6208
# 2  train_2       0   8.6093 -2.7457  12.0805  7.8928  10.5825 -9.0837  6.9427
# 3  train_3       0  11.0604 -2.1518   8.9522  7.1957  12.5846 -1.8361  5.8428
# 4  train_4       0   9.8369 -1.4834  12.8746  6.6375  12.2772  2.4486  5.9405
#
#      var_7   ...     var_190  var_191  var_192  var_193  var_194  var_195  \
# 0  18.6266   ...      4.4354   3.9642   3.1364   1.6910  18.5227  -2.3978
# 1  16.5338   ...      7.6421   7.7214   2.5837  10.9516  15.4305   2.0339
# 2  14.6155   ...      2.9057   9.7905   1.6704   1.6858  21.6042   3.1417
# 3  14.9250   ...      4.4666   4.7433   0.7178   1.4214  23.0347  -1.2706
# 4  19.2514   ...     -1.4905   9.5214  -0.1508   9.1942  13.2876  -1.5121
#
#    var_196  var_197  var_198  var_199
# ...

# %% [markdown]
# ## Check out here how to decrease memory of dataset.
# https://www.kaggle.com/mjbahmani/santander-ml-explainability

# %%
# Would like to calculate count for each data point, but not sure if useful

# df.groupby('a')['a'].transform('count')

# %% [markdown]
# ## Should do a predict_proba as done in this kernal
# https://www.kaggle.com/chocozzz/santander-lightgbm-baseline-lb-0-899
